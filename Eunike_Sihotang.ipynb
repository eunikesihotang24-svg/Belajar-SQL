# %% [markdown]
# <a id="A"></a>
# # <b>A. <span style='color:#0B2F9F'><code>SELECT</code></span></b>

# %% [markdown]
# <a id="A.1."></a>
# ## <b>A.1. <span style='color:#0B2F9F'>Menampilkan Semua Data pada Satu Tabel</span></b>
#
#
# # **SELECT * FROM (NAMA TABEL)**

# %% [markdown]
# #### <i><b><span style='color:#55679C'>Quest</span> : Tampilkan semua data pada tabel customer_status!</b></i>

# %%
SELECT * FROM `Costumer_status.Costumer_status`
# Out:
#      customer_id  satisfaction_score   status churn_label  churn_score  cltv  \
# 0     8779-QRDMV                   3  Churned         Yes           91  5433
# 1     7495-OOKFY                   3  Churned         Yes           69  5302
# 2     1658-BYGOY                   2  Churned         Yes           81  3179
# 3     4598-XLKNJ                   2  Churned         Yes           88  5337
# 4     4846-WHAFZ                   2  Churned         Yes           67  2793
# ...          ...                 ...      ...         ...          ...   ...
# 7038  2569-WGERO                   5   Stayed          No           45  5306
# 7039  6840-RESVB                   3   Stayed          No           59  2140
# 7040  2234-XADUH                   4   Stayed          No           71  5560
# 7041  4801-JZAZL                   4   Stayed          No           59  2793
# 7042  3186-AJIEK                   4   Stayed          No           38  5097
#
#        churn_category                  churn_reason
# 0          Competitor  Competitor offered more data
# 1          Competitor  Competitor made better offer
# 2          Competitor  Competitor made better offer
# 3     Dissatisfaction     Limited range of services
# 4               Price            Extra data charges
# ...               ...                           ...
# 7038             None                          None
# 7039             None                          None
# 7040             None                          None
# 7041             None                          None
# 7042             None                          None
#
# [7043 rows x 8 columns]

# %% [markdown]
# <a id="A.2."></a>
# ## <b>A.2. <span style='color:#0B2F9F'>Menampilkan Kolom Tertentu pada Satu Tabel</span></b>

# %% [markdown]
# #### <i><b><span style='color:#55679C'>Quest</span> : Tampilkan kolom customer_id, status dan churn_reason pada tabel customer_status!</b></i>

# %%
SELECT customer_id, status, churn_reason
FROM `eunike-sihotang-494313.Costumer_status.customer_status`;
# Out:
#      customer_id   status                  churn_reason
# 0     8779-QRDMV  Churned  Competitor offered more data
# 1     7495-OOKFY  Churned  Competitor made better offer
# 2     1658-BYGOY  Churned  Competitor made better offer
# 3     4598-XLKNJ  Churned     Limited range of services
# 4     4846-WHAFZ  Churned            Extra data charges
# ...          ...      ...                           ...
# 7038  2569-WGERO   Stayed                          None
# 7039  6840-RESVB   Stayed                          None
# 7040  2234-XADUH   Stayed                          None
# 7041  4801-JZAZL   Stayed                          None
# 7042  3186-AJIEK   Stayed                          None
#
# [7043 rows x 3 columns]

# %% [markdown]
# <a id="A.3."></a>
# ## <b>A.3. <span style='color:#0B2F9F'>Mengubah Penyebutan Nama Kolom pada Satu Tabel</span></b>

# %% [markdown]
# #### <i><b><span style='color:#55679C'>Quest</span> : Tampilkan kolom customer_id, cltv dan status pada tabel customer_status, namun ubah sementara nama kolom cltv menjadi customer_lifetime_value agar lebih mudah diinterpretasikan!</b></i>

# %%
SELECT customer_id,
       cltv AS customer_lifetime_value,
       status
FROM `eunike-sihotang-494313.Costumer_status.customer_status`;
# Out:
#      customer_id  customer_lifetime_value   status
# 0     8779-QRDMV                     5433  Churned
# 1     7495-OOKFY                     5302  Churned
# 2     1658-BYGOY                     3179  Churned
# 3     4598-XLKNJ                     5337  Churned
# 4     4846-WHAFZ                     2793  Churned
# ...          ...                      ...      ...
# 7038  2569-WGERO                     5306   Stayed
# 7039  6840-RESVB                     2140   Stayed
# 7040  2234-XADUH                     5560   Stayed
# 7041  4801-JZAZL                     2793   Stayed
# 7042  3186-AJIEK                     5097   Stayed
#
# [7043 rows x 3 columns]

# %% [markdown]
# <a id="B"></a>
# # <b>B. <span style='color:#E1B12D'><code>DISTINCT</code></span></b>

# %% [markdown]
# <a id="B.1."></a>
# ## <b>B.1. <span style='color:#0B2F9F'>Nilai Unik pada Satu Kolom Tertentu</span></b>

# %% [markdown]
# #### <i><b><span style='color:#55679C'>Quest</span> : Tampilkan apa saja jenis status pada tabel customer_status!</b></i>

# %%
SELECT DISTINCT *
FROM `eunike-sihotang-494313.Costumer_status.customer_status`;
# Out:
#      customer_id  satisfaction_score   status churn_label  churn_score  cltv  \
# 0     8779-QRDMV                   3  Churned         Yes           91  5433
# 1     7495-OOKFY                   3  Churned         Yes           69  5302
# 2     1658-BYGOY                   2  Churned         Yes           81  3179
# 3     4598-XLKNJ                   2  Churned         Yes           88  5337
# 4     4846-WHAFZ                   2  Churned         Yes           67  2793
# ...          ...                 ...      ...         ...          ...   ...
# 7038  2569-WGERO                   5   Stayed          No           45  5306
# 7039  6840-RESVB                   3   Stayed          No           59  2140
# 7040  2234-XADUH                   4   Stayed          No           71  5560
# 7041  4801-JZAZL                   4   Stayed          No           59  2793
# 7042  3186-AJIEK                   4   Stayed          No           38  5097
#
#        churn_category                  churn_reason
# 0          Competitor  Competitor offered more data
# 1          Competitor  Competitor made better offer
# 2          Competitor  Competitor made better offer
# 3     Dissatisfaction     Limited range of services
# 4               Price            Extra data charges
# ...               ...                           ...
# 7038             None                          None
# 7039             None                          None
# 7040             None                          None
# 7041             None                          None
# 7042             None                          None
#
# [7043 rows x 8 columns]

# %% [markdown]
# <a id="B.2."></a>
# ## <b>B.2. <span style='color:#0B2F9F'>Nilai Unik pada Lebih dari Satu Kolom</span></b>

# %% [markdown]
# #### <i><b><span style='color:#55679C'>Quest</span> : Tampilkan apa saja jenis churn_category dan churn_reason pada tabel customer_status!</b></i>

# %%
SELECT DISTINCT churn_category, churn_reason
FROM `eunike-sihotang-494313.Costumer_status.customer_status`;
# Out:
#      churn_category                               churn_reason
# 0        Competitor               Competitor offered more data
# 1        Competitor               Competitor made better offer
# 2   Dissatisfaction                  Limited range of services
# 3             Price                         Extra data charges
# 4        Competitor              Competitor had better devices
# 5             Other                                 Don't know
# 6   Dissatisfaction                    Service dissatisfaction
# 7             Price   Lack of affordable download/upload speed
# 8   Dissatisfaction                    Product dissatisfaction
# 9             Price                      Long distance charges
# 10  Dissatisfaction           Poor expertise of online support
# 11         Attitude                 Attitude of support person
# 12  Dissatisfaction                        Network reliability
# 13       Competitor  Competitor offered higher download speeds
# 14            Other           Poor expertise of online support
# 15            Other                                      Moved
# 16            Price                             Price too high
# 17         Attitude               Attitude of service provider
# 18  Dissatisfaction            Poor expertise of phone support
# 19            Other                                   Deceased
# 20             None                                       None
# 21  Dissatisfaction            Lack of self-service on Website

# %% [markdown]
# <a id="C"></a>
# # <b>C. <span style='color:#E1B12D'><code>LIMIT</code></span></b>

# %% [markdown]
# <a id="C.1."></a>
# ## <b>C.1. <span style='color:#0B2F9F'>Membatasi Jumlah Baris (yang ditampilkan) di Semua Kolom pada Data</span></b>

# %% [markdown]
# #### <i><b><span style='color:#55679C'>Quest</span> : Tampilkan semua 5 data teratas pada tabel customer_status!</b></i>

# %%
SELECT * FROM `eunike-sihotang-494313.Costumer_status.Costumer_status`
LIMIT 5
# Out:
#   customer_id  satisfaction_score   status churn_label  churn_score  cltv  \
# 0  8779-QRDMV                   3  Churned         Yes           91  5433
# 1  7495-OOKFY                   3  Churned         Yes           69  5302
# 2  1658-BYGOY                   2  Churned         Yes           81  3179
# 3  4598-XLKNJ                   2  Churned         Yes           88  5337
# 4  4846-WHAFZ                   2  Churned         Yes           67  2793
#
#     churn_category                  churn_reason
# 0       Competitor  Competitor offered more data
# 1       Competitor  Competitor made better offer
# 2       Competitor  Competitor made better offer
# 3  Dissatisfaction     Limited range of services
# 4            Price            Extra data charges

# %% [markdown]
# <a id="C.2."></a>
# ## <b>C.2. <span style='color:#0B2F9F'>Membatasi Jumlah Baris (yang ditampilkan) di Kolom Tertentu pada Data</span></b>

# %% [markdown]
# #### <i><b><span style='color:#55679C'>Quest</span> : Tampilkan 10 data teratas untuk kolom customer_id, status dan churn_reason pada tabel customer_status!</b></i>

# %%
SELECT Customer_id, Status, Churn_reason
FROM `eunike-sihotang-494313.Costumer_status.Costumer_status`
LIMIT 10
# Out:
#   customer_id   status                              churn_reason
# 0  8779-QRDMV  Churned              Competitor offered more data
# 1  7495-OOKFY  Churned              Competitor made better offer
# 2  1658-BYGOY  Churned              Competitor made better offer
# 3  4598-XLKNJ  Churned                 Limited range of services
# 4  4846-WHAFZ  Churned                        Extra data charges
# 5  4412-YLTKF  Churned             Competitor had better devices
# 6  0390-DCFDQ  Churned                                Don't know
# 7  3445-HXXGF  Churned                   Service dissatisfaction
# 8  2656-FMOKZ  Churned                 Limited range of services
# 9  2070-FNEXE  Churned  Lack of affordable download/upload speed

# %% [markdown]
# #### <i><b><span style='color:#55679C'>Quest</span> : Tampilkan 3 data teratas untuk kolom customer_id, cltv dan status pada tabel customer_status, namun ubah sementara nama kolom cltv menjadi customer_lifetime_value agar lebih mudah diinterpretasikan!</b></i>

# %%
SELECT Customer_id, Status, CLTV AS Customer_lifetime_value
FROM `eunike-sihotang-494313.Costumer_status.Costumer_status`
LIMIT 3
# Out:
#   customer_id  customer_lifetime_value   status
# 0  8779-QRDMV                     5433  Churned
# 1  7495-OOKFY                     5302  Churned
# 2  1658-BYGOY                     3179  Churned

# %% [markdown]
# <a id="D"></a>
# # <b>D. <span style='color:#E1B12D'><code>ORDER BY</code></span></b>

# %% [markdown]
# <a id="D.1."></a>
# ## <b>D.1. <span style='color:#0B2F9F'>Mengurutkan secara <i>Ascending</i></span></b>

# %% [markdown]
# #### <i><b><span style='color:#55679C'>Quest</span> : Tampilkan semua data pada tabel customer_status namun urutkan berdasarkan kolom customer_id secara ascending!</b></i>

# %%
SELECT * FROM `eunike-sihotang-494313.Costumer_status.Costumer_status`
ORDER BY Customer_id ASC
# Out:
#      customer_id  satisfaction_score   status churn_label  churn_score  cltv  \
# 0     0002-ORFBO                   3   Stayed          No           65  2205
# 1     0003-MKNFE                   5   Stayed          No           66  5414
# 2     0004-TLHLJ                   1  Churned         Yes           71  4479
# 3     0011-IGKFF                   1  Churned         Yes           91  3714
# 4     0013-EXCHZ                   1  Churned         Yes           68  3464
# ...          ...                 ...      ...         ...          ...   ...
# 7038  9987-LUTYD                   4   Stayed          No           59  3161
# 7039  9992-RRAMN                   1  Churned         Yes           68  5248
# 7040  9992-UJOEL                   5   Joined          No           33  5870
# 7041  9993-LHIEB                   3   Stayed          No           59  4792
# 7042  9995-HOTOH                   3   Stayed          No           20  5639
#
#        churn_category                   churn_reason
# 0                None                           None
# 1                None                           None
# 2          Competitor  Competitor had better devices
# 3     Dissatisfaction        Product dissatisfaction
# 4     Dissatisfaction            Network reliability
# ...               ...                            ...
# 7038             None                           None
# 7039  Dissatisfaction        Product dissatisfaction
# 7040             None                           None
# 7041             None                           None
# 7042             None                           None
#
# [7043 rows x 8 columns]

# %% [markdown]
# <a id="D.2."></a>
# ## <b>D.2. <span style='color:#0B2F9F'>Mengurutkan secara <i>Descending</i></span></b>

# %% [markdown]
# #### <i><b><span style='color:#55679C'>Quest</span> : Tampilkan semua data pada tabel customer_status namun urutkan berdasarkan kolom cltv secara descending!</b></i>

# %%
SELECT * FROM `eunike-sihotang-494313.Costumer_status.Costumer_status`
ORDER BY cltv DESC
# Out:
#      customer_id  satisfaction_score   status churn_label  churn_score  cltv  \
# 0     7622-FWGEW                   3   Stayed          No           70  6500
# 1     6024-RUGGH                   3   Stayed          No           62  6499
# 2     0383-CLDDA                   3   Stayed          No           37  6499
# 3     2683-JXWQQ                   3   Stayed          No           64  6495
# 4     8894-JVDCV                   4   Stayed          No           43  6494
# ...          ...                 ...      ...         ...          ...   ...
# 7038  0247-SLUJI                   5   Joined          No           43  2004
# 7039  4657-FWVFY                   5   Stayed          No           52  2004
# 7040  6860-YRJZP                   5   Stayed          No           51  2003
# 7041  4925-LMHOK                   2  Churned         Yes           90  2003
# 7042  0871-URUWO                   1  Churned         Yes           66  2003
#
#        churn_category                   churn_reason
# 0                None                           None
# 1                None                           None
# 2                None                           None
# 3                None                           None
# 4                None                           None
# ...               ...                            ...
# 7038             None                           None
# 7039             None                           None
# 7040             None                           None
# 7041  Dissatisfaction        Service dissatisfaction
# 7042       Competitor  Competitor had better devices
#
# [7043 rows x 8 columns]

# %% [markdown]
# <a id="D.3."></a>
# ## <b>D.3. <span style='color:#0B2F9F'>Kombinasi <i>Ascending</i> & <i>Descending</i> saat Mengurutkan Data</span></b>

# %% [markdown]
# #### <i><b><span style='color:#55679C'>Quest</span> : Tampilkan 10 data pada tabel customer_status namun urutkan berdasarkan customer_id dari yang terkecil hingga yang terbesar dan urutkan pula cltv dari yang terbesar hingga yang terkecil!</b></i>

# %%
SELECT * FROM `eunike-sihotang-494313.Costumer_status.Costumer_status`
ORDER BY customer_id ASC, cltv DESC
LIMIT 10
# Out:
#   customer_id  satisfaction_score   status churn_label  churn_score  cltv  \
# 0  0002-ORFBO                   3   Stayed          No           65  2205
# 1  0003-MKNFE                   5   Stayed          No           66  5414
# 2  0004-TLHLJ                   1  Churned         Yes           71  4479
# 3  0011-IGKFF                   1  Churned         Yes           91  3714
# 4  0013-EXCHZ                   1  Churned         Yes           68  3464
# 5  0013-MHZWF                   3   Stayed          No           55  5108
# 6  0013-SMEOE                   3   Stayed          No           26  5011
# 7  0014-BMAQU                   4   Stayed          No           49  4604
# 8  0015-UOCOJ                   3   Stayed          No           34  5525
# 9  0016-QLJIS                   3   Stayed          No           25  5509
#
#     churn_category                   churn_reason
# 0             None                           None
# 1             None                           None
# 2       Competitor  Competitor had better devices
# 3  Dissatisfaction        Product dissatisfaction
# 4  Dissatisfaction            Network reliability
# 5             None                           None
# 6             None                           None
# 7             None                           None
# 8             None                           None
# 9             None                           None

# %% [markdown]
# #### <i><b><span style='color:#55679C'>Quest</span> : Siapa saja customer yang berada di top 10 nilai cltv terbesar? Tampilkan kolom customer_id, cltv dan status pada tabel customer_status, namun ubah sementara nama kolom cltv menjadi customer_lifetime_value agar lebih mudah diinterpretasikan</b></i>

# %%
SELECT Customer_id, cltv AS Customer_lifetime_value, Status
FROM `eunike-sihotang-494313.Costumer_status.Costumer_status`
ORDER BY cltv DESC
LIMIT 10
# Out:
#   customer_id  customer_lifetime_value  status
# 0  7622-FWGEW                     6500  Stayed
# 1  6024-RUGGH                     6499  Stayed
# 2  0383-CLDDA                     6499  Stayed
# 3  2683-JXWQQ                     6495  Stayed
# 4  8894-JVDCV                     6494  Stayed
# 5  4114-QMKVN                     6494  Stayed
# 6  1658-XUHBX                     6492  Stayed
# 7  4531-AUZNK                     6492  Stayed
# 8  2181-TIDSV                     6492  Stayed
# 9  0675-NCDYU                     6491  Stayed
